# %% [markdown]
# # WASP-119
#
# In this notebook, we use *eleanor* to get the raw, corrected and PCA light curves for a target named WASP-119. The target is located in the constellation of Reticulum (where WASP-100 is also located). We use the target's name to download all the required information with *eleanor* for TESS's Sector 1.
#
# WASP-119 has been confirmed to have an exoplanet in both DACE and the NASA Exoplanet Catalog.
#
#
# **DACE:** https://dace.unige.ch/dashboard/
#
# **NASA Exoplanet Catalog:** https://exoplanets.nasa.gov/discovery/exoplanet-catalog/

# %%
# Connect to Google Drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Install the *eleanor* pipeline. We need to install every time the notebook gets disconnected from the Google Drive.

# %%
pip install eleanor
# Out:
# Collecting eleanor
#   Downloading eleanor-2.0.5.tar.gz (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting nbsphinx (from eleanor)
#   Downloading nbsphinx-0.9.3-py3-none-any.whl (31 kB)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from eleanor) (5.5.6)
# Collecting photutils (from eleanor)
#   Downloading photutils-1.9.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from eleanor) (4.66.1)
# Collecting lightkurve (from eleanor)
#   Downloading lightkurve-2.4.2-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 kB 32.0 MB/s eta 0:00:00
# Requirement already satisfied: astropy>=3.2.3 in /usr/local/lib/python3.10/dist-packages (from eleanor) (5.3.4)
# Collecting astroquery (from eleanor)
#   Downloading astroquery-0.4.6-py3-none-any.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 53.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from eleanor) (1.5.3)
# Collecting tess-point (from eleanor)
#   Downloading tess-point-0.8.0.tar.gz (22 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from eleanor) (67.7.2)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from eleanor) (4.11.2)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from astropy>=3.2.3->eleanor) (1.23.5)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=3.2.3->eleanor) (2.0.1.1)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy>=3.2.3->eleanor) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=3.2.3->eleanor) (23.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.6.0->eleanor) (2.5)
# Requirement already satisfied: requests>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from astroquery->eleanor) (2.31.0)
# Requirement already satisfied: html5lib>=0.999 in /usr/local/lib/python3.10/dist-packages (from astroquery->eleanor) (1.1)
# Requirement already satisfied: keyring>=4.0 in /usr/lib/python3/dist-packages (from astroquery->eleanor) (23.5.0)
# Collecting pyvo>=1.1 (from astroquery->eleanor)
#   Downloading pyvo-1.4.2-py3-none-any.whl (888 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.9/888.9 kB 38.1 MB/s eta 0:00:00
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->eleanor) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->eleanor) (7.34.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->eleanor) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->eleanor) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->eleanor) (6.3.2)
# Requirement already satisfied: bokeh>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from lightkurve->eleanor) (3.2.2)
# Collecting fbpca>=1.0 (from lightkurve->eleanor)
#   Downloading fbpca-1.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib>=3.1 in /usr/local/lib/python3.10/dist-packages (from lightkurve->eleanor) (3.7.1)
# Collecting memoization>=0.3.1 (from lightkurve->eleanor)
#   Downloading memoization-0.4.0.tar.gz (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting oktopus>=0.1.2 (from lightkurve->eleanor)
#   Downloading oktopus-0.1.2.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: patsy>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from lightkurve->eleanor) (0.5.3)
# Requirement already satisfied: scikit-learn>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from lightkurve->eleanor) (1.2.2)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from lightkurve->eleanor) (1.11.3)
# Collecting uncertainties>=3.1.4 (from lightkurve->eleanor)
#   Downloading uncertainties-3.1.7-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.23 in /usr/local/lib/python3.10/dist-packages (from lightkurve->eleanor) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->eleanor) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->eleanor) (2023.3.post1)
# Requirement already satisfied: docutils in /usr/local/lib/python3.10/dist-packages (from nbsphinx->eleanor) (0.18.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from nbsphinx->eleanor) (3.1.2)
# Requirement already satisfied: nbconvert!=5.4 in /usr/local/lib/python3.10/dist-packages (from nbsphinx->eleanor) (6.5.4)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from nbsphinx->eleanor) (5.9.2)
# Requirement already satisfied: sphinx>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbsphinx->eleanor) (5.0.2)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.0.0->lightkurve->eleanor) (1.1.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.0.0->lightkurve->eleanor) (9.4.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.0.0->lightkurve->eleanor) (2023.10.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery->eleanor) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery->eleanor) (0.5.1)
# Collecting jedi>=0.16 (from ipython>=5.0.0->ipykernel->eleanor)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 69.4 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->eleanor) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->eleanor) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->eleanor) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->eleanor) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->eleanor) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->eleanor) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->eleanor) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->nbsphinx->eleanor) (2.1.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->lightkurve->eleanor) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->lightkurve->eleanor) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->lightkurve->eleanor) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->lightkurve->eleanor) (3.1.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx->eleanor) (4.9.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx->eleanor) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx->eleanor) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx->eleanor) (0.4)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx->eleanor) (5.4.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx->eleanor) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx->eleanor) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx->eleanor) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx->eleanor) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx->eleanor) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->nbsphinx->eleanor) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->nbsphinx->eleanor) (4.19.1)
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from oktopus>=0.1.2->lightkurve->eleanor) (1.6.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery->eleanor) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery->eleanor) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery->eleanor) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.0->lightkurve->eleanor) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.0->lightkurve->eleanor) (3.2.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx->eleanor) (1.0.7)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx->eleanor) (1.0.5)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx->eleanor) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx->eleanor) (2.0.4)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx->eleanor) (1.1.9)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx->eleanor) (1.0.6)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx->eleanor) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx->eleanor) (2.13.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx->eleanor) (0.7.13)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx->eleanor) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from uncertainties>=3.1.4->lightkurve->eleanor) (0.18.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->eleanor) (23.2.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->eleanor) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx->eleanor) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx->eleanor) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx->eleanor) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx->eleanor) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.7->nbconvert!=5.4->nbsphinx->eleanor) (3.11.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel->eleanor) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->eleanor) (0.2.8)
# Building wheels for collected packages: eleanor, tess-point, fbpca, memoization, oktopus
#   Building wheel for eleanor (setup.py) ... done
#   Created wheel for eleanor: filename=eleanor-2.0.5-py2.py3-none-any.whl size=144466 sha256=2a8908974692631f96478fce07443998a5f7c386c54710d24d324f3b77ec7f7f
#   Stored in directory: /root/.cache/pip/wheels/19/40/58/c3985f6641af96942f371804d5c27d6dba1447ca761e3c4299
#   Building wheel for tess-point (setup.py) ... done
#   Created wheel for tess-point: filename=tess_point-0.8.0-py3-none-any.whl size=24043 sha256=4f2d74b838ec85b25bb024e758859c195538db556be4175251fb914459acb45d
#   Stored in directory: /root/.cache/pip/wheels/75/67/db/5a3e065484192bd2805bd0d341390d4ca21ff455bc770a158b
#   Building wheel for fbpca (setup.py) ... done
#   Created wheel for fbpca: filename=fbpca-1.0-py3-none-any.whl size=11373 sha256=7c9dadbd5c478a8abf29312e493946782a7ce87ce71d4b9316fa7669a1a0eac7
#   Stored in directory: /root/.cache/pip/wheels/3c/ea/60/8d1c9fbbc99492a1775b36a5e29c8c1ef309cc5821bd5a219d
#   Building wheel for memoization (setup.py) ... done
#   Created wheel for memoization: filename=memoization-0.4.0-py3-none-any.whl size=50452 sha256=ab47caf4f3f26206fac21ed4d7ffbb7b4a37b18d9967b1e927d36932a1bcaa27
#   Stored in directory: /root/.cache/pip/wheels/3e/b8/c5/b553d5e8b0249bd2859b3b6d7bb2a1849e7b01c6e8b64f6e87
#   Building wheel for oktopus (setup.py) ... done
#   Created wheel for oktopus: filename=oktopus-0.1.2-py3-none-any.whl size=12762 sha256=2ccb052d5f79bc45ea532b7494bd83de9c8dc19eda3fa56d8f7b7346ace0d974
#   Stored in directory: /root/.cache/pip/wheels/b6/55/53/8d7c151deab7a11f182e5a69feb906cab95123da7a2438ed9d
# Successfully built eleanor tess-point fbpca memoization oktopus
# Installing collected packages: fbpca, uncertainties, memoization, jedi, oktopus, tess-point, pyvo, photutils, astroquery, lightkurve, nbsphinx, eleanor
# Successfully installed astroquery-0.4.6 eleanor-2.0.5 fbpca-1.0 jedi-0.19.1 lightkurve-2.4.2 memoization-0.4.0 nbsphinx-0.9.3 oktopus-0.1.2 photutils-1.9.0 pyvo-1.4.2 tess-point-0.8.0 uncertainties-3.1.7

# %%
# Import "Image" class to display images in the notebook.
from IPython.display import Image

# Instruct Python to ignore and not display warning messages.
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the necessary modules.
import eleanor
import numpy as np
from astropy import units as u
import matplotlib.pyplot as plt
from astropy.coordinates import SkyCoord

plt.rcParams['font.size'] = 16   # Set the font size for text.

# %% [markdown]
# ## Initiating *eleanor.Source*
#
# Choosing the target star and the sector it was observed in. Here we used the coordinates for WASP-119, in Sector 1.

# %%
star = eleanor.Source(name='WASP-119', sector=1)
# Out:
# Most recent sector available =  69
# Downloading URL https://mast.stsci.edu/tesscut/api/v0.1/astrocut?ra=68.95970833333332&dec=-64.02703611111112&y=31&x=31&units=px&sector=1 to ./tesscut_20231105122054.zip ... [Done]
# Inflating...
# This is the first light curve you have made for this sector. Getting eleanor metadata products for Sector  1...
# This will only take a minute, and only needs to be done once. Any other light curves you make in this sector will be faster.
# Acquiring target...
# Calculating Cadences...
# Assuring Quality Flags...
# Making CBVs...
# Success! Sector  1 now available.
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HLSP/eleanor/postcards/s0001/4-1/hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0804-0052_tess_v2_bkg.fits to ./mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0804-0052_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0804-0052_tess_v2_bkg.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HLSP/eleanor/postcards/s0001/4-1/hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0804-0052_tess_v2_pc.fits to ./mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0804-0052_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0804-0052_tess_v2_pc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HLSP/eleanor/postcards/s0001/4-1/hlsp_eleanor_tess_ffi_postcard-s0001-4-1_tess_v2_pm.txt to ./mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0804-0052_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-4-1_tess_v2_pm.txt ... [Done]

# %% [markdown]
# Now that everything has been downloaded, we can check the different ID numbers (TIC and Gaia) and coordinates (RA and Dec) from the
#
# cross-checking eleanor has done.

# %%
star.tic, star.coords, star.gaia
# Out:
# (388104525, (55.93342166666667, -65.19385083333334), 4672607178880426624)

# %% [markdown]
# We can also get information on where the target was observed on the TESS CCD cameras.

# %%
star.sector, star.camera, star.chip
# Out:
# (1, 4, 1)

# %% [markdown]
# ## Making a light curve
#
# We now have everything we need to make a light curve.

# %%
# Creating a PCA light curve for the target star.
data = eleanor.TargetData(star, do_pca=True)

# %% [markdown]
# The eleanor light curves are tailored to find transits. So, it's trying to minimise the combined differential photometric precision (noise out of transit). We can do three different background subtractions:
#
# 1. 1D postcard background: constant value that is calculated for each postcard frame, masking all the stars in that region.
#   - data.bkg_type = 'PC_LEVEL' : keyword = data.flux_bkg
# 2. 1D TPF (target pixel file) background: constant value calculated for each TPF frame, masking all the stars in that region.
#   - 1D TPF background : data.bkg_type = 'TPF_LEVEL' : keyword = data.tpf_flux_bkg
# 3. 2D background: a model background that the developers created and was downloaded when we created the *eleanor.Source* object.
#   - data.bkg_type = 'TPF_2D_LEVEL' : keyword = data.bkg_tpf (post_obj.background2d)
#
#
# An example of a 2D background is shown in the plot below.

# %%
plt.title('2D background')
plt.imshow(data.post_obj.background2d[100], vmin=0, vmax=20)
plt.colorbar();

# %% [markdown]
# There are a lot of stars in this field and we can see the bright regions used for background subtraction.

# %% [markdown]
# Below we can see which background produced the best light curve. The result is "PC_LEVEL", meaning that the 1D level background removed the most systematics.

# %%
data.bkg_type
# Out:
# 'PC_LEVEL'

# %% [markdown]
# Below we plot the background flux (energy received per unit area) over time (BJD).
#
#
#
# ---
#
#
# **BJD:** Barycentric Julian Date, the Julian Date corrected for differences in the Earth's position with respect to the barycentre of the Solar System. Due to the finite speed of light, the time an astronomical event is observed depends on the changing position of the observer in the Solar System. Before multiple observations can be combined, they must be reduced to a common, fixed, reference location. This correction also depends on the direction to the object or event being timed.

# %%
plt.figure(figsize=(14, 4))
plt.plot(data.time, data.post_obj.bkg, 'b', lw=3)        # Changed the line colour from 'w' to 'b' to see it.
plt.xlabel('time (bjd-2457000)')
plt.ylabel('background flux');

# %% [markdown]
# *eleanor* also tests an entire suite of apertures. The aperture selected by *eleanor* also minimises CDPP. So, by testing all the different apertures with the different backgrounds, we hope to get the cleanest light curve for transits as possible. The aperture over the selected target is shown below.

# %%
plt.imshow(data.tpf[100])
plt.imshow(data.aperture, alpha=0.4, cmap='Greys_r');

# %% [markdown]
# The brighter/more yellow areas show the location of the star. The further away we get from the star the less energy we can receive from those areas.

# %% [markdown]
# We can also use the *eleanor.Visualise* class. We pass in the data from the *eleanor.TargetData* object and can overplot the contour, set colours, etc.

# %%
vis = eleanor.Visualize(data)
fig = vis.aperture_contour()
plt.gca().invert_yaxis()

# %% [markdown]
# ## Plotting the light curve

# %%
q = data.quality == 0         # Mask bad cadences with the quality flags set by the developers.

plt.figure(figsize=(14,4))    # Set figure size.

#plt.plot(data.time[q], data.raw_flux[q]/np.nanmedian(data.raw_flux[q]) - 0.005, 'b', lw=3, label='RAW')
plt.plot(data.time[q], data.corr_flux[q]/np.nanmedian(data.corr_flux[q]) + 0.01, 'k', lw=3, label='CORR')

# Moved this line of code from the top to get a more consistent legend.
plt.plot(data.time[q], data.raw_flux[q]/np.nanmedian(data.raw_flux[q]) - 0.015, 'b', lw=3, label='RAW')

plt.ylim(0.96, 1.04)               # This line is used in the tutorial. It just changes the limits of the y-axis.
plt.ylabel('Normalized Flux')
plt.xlabel('Time [BJD - 2457000]')
plt.title('WASP-119')
plt.legend();

# %%
q = data.quality == 0         # Mask bad cadences witht he quality flags det by the developers.

plt.figure(figsize=(14,6))    # Set figure size.

plt.plot(data.time[q], data.raw_flux[q]/np.nanmedian(data.raw_flux[q]) + 0.06, 'k', label='RAW')
plt.plot(data.time[q], data.corr_flux[q]/np.nanmedian(data.corr_flux[q]) + 0.03, 'darkorange', label='CORR')
plt.plot(data.time[q], data.pca_flux[q]/np.nanmedian(data.pca_flux[q]), 'b', label='PCA')
#plt.plot(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q]) - 0.02, 'b')
plt.ylim(0.98, 1.08)
plt.ylabel('Normalized Flux')
plt.xlabel('Time [BJD - 2457000]')
plt.title('WASP-119, S1, Lightcurves')
#plt.legend(loc='best');
#plt.legend(loc='upper left', bbox_to_anchor=(1, 1));
plt.legend(ncol=3);

# %% [markdown]
# By calling *eleanor.to_lightkurve()*, we will get a *lightkurve.LightCurve* object. We can specify which flux we want passed into the object.
#
# This is also used to download the light curves from the TASOC and Oelkers & Stassun pipelines, for comparison.

# %%
lc = data.to_lightkurve(flux=data.corr_flux)

# %%
lc.normalize().plot();

# %%
# Setting limits to the y-axis.
lc.normalize().plot()
plt.ylim(0.985, 1.003);

# %% [markdown]
# ## Crossmatching
#
# Within *eleanor*, we also have tools to see if our target has a light curve produced by the TASOC team (TESS Asteroseismic Consortium), Oelkers & Stassun difference imaging pipeline, or was observed at a 2-minute cadence.

# %%
crossmatch = eleanor.Crossmatch(data)

# %% [markdown]
# To check for 2-minute data, we use *lightkurve* behind the scenes.

# %%
crossmatch.two_minute()
# Out:
# SearchResult containing 2 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 01 2018      SPOC     120   388104525      0.0
#   1 TESS Sector 01 2018 TESS-SPOC    1800   388104525      0.0

# %% [markdown]
# Because this returns a *lightkurve.SearchResult* object, we can download the data product right from there and go about using the other *lightkurve* tools.
#
#
# ---
#
# To check out the TASOC pipeline, we use *astro query* behind the scenes to get the data products from MAST (Mikulski Archive for Space Telescopes) and plot the light curve. They have their own quality flags so we can use those.

# %%
crossmatch.tasoc_lc()
# Out:
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HLSP/tasoc/s0001/c1800/0000/0003/8810/4525/hlsp_tasoc_tess_ffi_tic00388104525-s0001-cam4-ccd1-c1800_tess_v05_cbv-lc.fits to /root/.eleanor/mastDownload/HLSP/hlsp_tasoc_tess_ffi_tic00388104525-s0001-cam4-ccd1-c1800_tess_v05/hlsp_tasoc_tess_ffi_tic00388104525-s0001-cam4-ccd1-c1800_tess_v05_cbv-lc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HLSP/tasoc/s0001/c1800/0000/0003/8810/4525/hlsp_tasoc_tess_ffi_tic00388104525-s0001-cam4-ccd1-c1800_tess_v05_ens-lc.fits to /root/.eleanor/mastDownload/HLSP/hlsp_tasoc_tess_ffi_tic00388104525-s0001-cam4-ccd1-c1800_tess_v05/hlsp_tasoc_tess_ffi_tic00388104525-s0001-cam4-ccd1-c1800_tess_v05_ens-lc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HLSP/tasoc/s0001/c0120/0000/0003/8810/4525/hlsp_tasoc_tess_tpf_tic00388104525-s0001-cam4-ccd1-c0120_tess_v05_cbv-lc.fits to /root/.eleanor/mastDownload/HLSP/hlsp_tasoc_tess_tpf_tic00388104525-s0001-cam4-ccd1-c0120_tess_v05/hlsp_tasoc_tess_tpf_tic00388104525-s0001-cam4-ccd1-c0120_tess_v05_cbv-lc.fits ... [Done]

# %%
plt.figure(figsize=(14,4))
q = crossmatch.tasoc_pixel_quality == 0      # Can use TASOC quality flags.
plt.plot(crossmatch.tasoc_time[q], crossmatch.tasoc_flux_raw[q], 'k', lw=1)
# plt.ylim(13300,13600)
plt.title('WASP-119 TASOC Light Curve')
plt.xlabel('time [BJD - 2457000]')
plt.ylabel('flux');

# %% [markdown]
# This particular light curve seems to include a lot of noise. However, the transits are clearly visible. There is also a feature right before time=1350, that appears in most TASOC light curves that we have downloaded. It is possible that the feature is the result of an issue that may have occured with the TESS satellite at that particular date.

# %% [markdown]
# Then we check the Oelkers & Stassun light curves (it should be noted these light curves are in magnitudes, which is why they look
#
# upside-down).

# %%
crossmatch.oelkers_lc()

# %%
plt.figure(figsize=(14,4))
plt.plot(crossmatch.os_time, crossmatch.os_mag, 'b', lw=1)
plt.title('WASP-119 OS19 Light Curve')
plt.xlabel('time [BJD - 2457000]')
plt.ylabel('magnitude');

# %% [markdown]
# ## Comparison plot
#
# We can now plot all light curves together and compare.

# %%
plt.figure(figsize=(14,8))

e = data.quality == 0

plt.plot(crossmatch.os_time, 10**(-0.4*crossmatch.os_mag)/np.nanmedian(10**(-0.4*crossmatch.os_mag)), 'k', label='OS19', lw=1.5)

plt.plot(crossmatch.tasoc_time[q], crossmatch.tasoc_flux_raw[q]/np.nanmedian(crossmatch.tasoc_flux_raw[q])-0.035, 'royalblue', label='TASOC', lw=1.5)

plt.plot(data.time[e], data.corr_flux[e]/np.nanmedian(data.corr_flux[e])-0.08, 'red', label='eleanor', lw=1.5)

plt.legend(ncol=3)
plt.title('WASP-119, S1, Comparison')
plt.xlabel('Time [BJD-2457000]')
plt.ylabel('Flux')
plt.ylim(0.9, 1.03);

# %% [markdown]
# Here we see that we get the same number of transits from all pipelines (11 dips) and they all happen on the same time coordinate. Most of the noise has been reduced in *eleanor* and the TASOC feature (at around time=1350) has been completely smoothed out.
#
# This proves that *eleanor* can produce accurate light curves for WASP-119.
